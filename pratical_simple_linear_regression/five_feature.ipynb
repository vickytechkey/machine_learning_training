# %%
import pandas as pd

# Creating the dataset
data = {
    'Product_Weight': [500,750,300,1000,650,400,850,550,420,920],
    'Product_Volume': [0.8,1.2,0.5,1.5,1.0,0.6,1.4,0.9,0.7,1.3],
    'Shipping_Distance': [120,200,75,250,180,90,220,150,100,230],
    'Discount_Percent': [5,10,0,15,7,3,12,6,2,13],
    'Delivery_Time': [3.5,4.8,2.2,6.1,4.3,2.8,5.4,3.9,2.6,5.8]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Product_Weight  Product_Volume  Shipping_Distance  Discount_Percent  \
# 0             500             0.8                120                 5
# 1             750             1.2                200                10
# 2             300             0.5                 75                 0
# 3            1000             1.5                250                15
# 4             650             1.0                180                 7
# 5             400             0.6                 90                 3
# 6             850             1.4                220                12
# 7             550             0.9                150                 6
# 8             420             0.7                100                 2
# 9             920             1.3                230                13
#
#    Delivery_Time
# 0            3.5
# 1            4.8
# 2            2.2
# 3            6.1
# 4            4.3
# 5            2.8
# 6            5.4
# 7            3.9
# 8            2.6
# ...

# %%
df.corr()
# Out:
#                    Product_Weight  Product_Volume  Shipping_Distance  \
# Product_Weight           1.000000        0.987683           0.990852
# Product_Volume           0.987683        1.000000           0.988097
# Shipping_Distance        0.990852        0.988097           1.000000
# Discount_Percent         0.995204        0.985360           0.984231
# Delivery_Time            0.994169        0.982768           0.991775
#
#                    Discount_Percent  Delivery_Time
# Product_Weight             0.995204       0.994169
# Product_Volume             0.985360       0.982768
# Shipping_Distance          0.984231       0.991775
# Discount_Percent           1.000000       0.995642
# Delivery_Time              0.995642       1.000000
