# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data_banknote_authentication.csv')

# %%
df.count()
# Out:
# 3.6216      1371
# 8.6661      1371
# -2.8073     1371
# -0.44699    1371
# 0           1371
# dtype: int64
